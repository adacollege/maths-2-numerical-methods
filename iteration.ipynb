# %% [markdown]
# # Numerical Methods
#
# Show that $x^3-3x^2-2x+5=0$ has a *root* in the *interval* $3<x<4$

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
plt.style.use('ggplot')

# %% [markdown]
# Show that
# $$x^3-3x^2-2x+5=0$$
# can be rewritten as
# $$x=\sqrt{\dfrac{x^3-2x+5}{3}}$$

# %% [markdown]
# Use desmos to plot the graphs of $y=x$ and $y=\sqrt{\dfrac{x^3-2x+5}{3}}$

# %% [markdown]
# Where do the two graphs intersect? What does that mean?

# %%
xs = np.linspace(-2,6,100)
y1s = xs
y2s = np.sqrt((xs**3-2*xs+5)/3)

plt.plot(xs,y1s)
plt.plot(xs,y2s);

# %%
xs = np.linspace(-2,4,100)
y1s = xs
y2s = (xs**3-3*xs**2+5)/2

plt.plot(xs,y1s)
plt.plot(xs,y2s);

# %%
xs = np.linspace(-2,4,100)
y1s = xs
y2s = np.cbrt(3*xs**2+2*xs-5)

plt.plot(xs,y1s)
plt.plot(xs,y2s);

# %%
#rearranged version
def f(x):
    return (x**3-3*x**2+5)/2

# %%
#The original function
def g(x):
    return x**3-3*x**2-2*x+5

# %%
def root_between(a,b):
    if(g(a)*g(b)< 0):
        return True
    else:
        return False

# %%
root_between(3,4)
# Out:
# Works?
# True

# %%
def correctTo(sf, a1, a2):
    counter = 0;
    while counter < sf:
        if(str(a1).charAt(counter) != str.charAt(counter)):
            return False
        counter += 1
    return True

# %%
def iteration(max):
# Out:
# 13
